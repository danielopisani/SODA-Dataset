# %%
# Notebook Setup
# %cd /notebooks
import os
HOME = os.getcwd()
print(HOME)

# Pip install method
# !pip install ultralytics==8.0.20
# !pip install roboflow --quiet

from IPython import display
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
from roboflow import Roboflow

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# Import Dataset
rf = Roboflow(api_key="2vNzUkqiG7v3Cq182eZh")
project = rf.workspace("aerial-imagery-small-objects").project("aerial_imagery_05m")
dataset = project.version(10).download("yolov8")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Setup complete ✅ (8 CPUs, 44.1 GB RAM, 83.7/244.2 GB disk)
# mkdir: cannot create directory ‘/notebooks/datasets’: File exists
# /notebooks/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=500 imgsz=640 plots=True cache=False
# Out:
# /notebooks
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=val model='runs/detect/train4/weights/best.pt' data={dataset.location}/data.yaml imgsz=640
# Out:
# /notebooks
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /notebooks/datasets/aerial_imagery_05m-10/valid/labels... 344 imag
# val: New cache created: /notebooks/datasets/aerial_imagery_05m-10/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        344        212      0.865      0.815       0.86      0.683
#   clear_plastic_bottle        344         52       0.88      0.885      0.897      0.721
#              drink_can        344         92      0.944      0.859      0.912       0.74
#           drink_carton        344         15      0.901      0.867      0.917      0.775
#           glass_bottle        344         21      0.838       0.81      0.861      0.672
#              glass_jar        344         16      0.746      0.562      0.643      0.461
# ...
