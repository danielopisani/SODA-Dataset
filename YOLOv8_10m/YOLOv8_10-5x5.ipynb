# %%
# Notebook Setup
# %cd /notebooks
import os
HOME = os.getcwd()
print(HOME)

# Pip install method
# !pip install ultralytics==8.0.20
# !pip install roboflow --quiet

from IPython import display
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
from roboflow import Roboflow

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# Import Dataset
rf = Roboflow(api_key="2vNzUkqiG7v3Cq182eZh")
project = rf.workspace("aerial-imagery-small-objects").project("aerial_imagery_10m")
dataset = project.version(10).download("yolov8")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Setup complete ✅ (8 CPUs, 44.1 GB RAM, 82.4/244.2 GB disk)
# mkdir: cannot create directory ‘/notebooks/datasets’: File exists
# /notebooks/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=500 imgsz=640 plots=True cache=False
# Out:
# /notebooks
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=val model='runs/detect/train8/weights/best.pt' data={dataset.location}/data.yaml imgsz=640
# Out:
# /notebooks
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /notebooks/datasets/aerial_imagery_10m-10/valid/labels... 106 imag
# val: New cache created: /notebooks/datasets/aerial_imagery_10m-10/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        106        122      0.642      0.646      0.671      0.474
#   clear_plastic_bottle        106         29      0.775      0.793      0.816      0.563
#              drink_can        106         64      0.869      0.827      0.873      0.601
#           drink_carton        106          7      0.586      0.714      0.691      0.568
#           glass_bottle        106         12      0.854      0.667      0.731      0.462
#              glass_jar        106          2          0          0          0          0
# ...
